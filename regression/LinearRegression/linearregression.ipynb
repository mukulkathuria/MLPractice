# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/highskewed.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   A           1000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB
# None

# %%
df = df.drop(columns='Unnamed: 0')

# %%
print(df.describe())
# Out:
#                  A
# count  1000.000000
# mean      6.125590
# std      24.549688
# min       0.001848
# 25%       0.295960
# 50%       1.146073
# 75%       4.396147
# max     629.085874

# %%
count = 300
target = {}
print(df)
for column in df.columns:
    for j in range(len(column)):
        print(j)
        # if df.loc[j, column] > 2:
        #     count = count + 1
        #     print(count)
        #     target['target'] = count
        # else:
        #     target['target'] = 0
# print("Target", target['target'])
# Out:
#              A  target
# 0     0.168370       0
# 1     2.407482       0
# 2     2.560306     305
# 3     0.291841     305
# 4     2.161998     305
# ..         ...     ...
# 995   0.503296  104920
# 996  14.432121  105225
# 997  20.134802  105530
# 998   0.019532  105530
# 999   1.514942  105530
#
# [1000 rows x 2 columns]
# 0
# 0
# 1
# 2
# 3
# 4
# 5

# %%
import seaborn as sns
sns.scatterplot(data=df, x='A', y='target', hue='target')
# Out:
# <Axes: xlabel='A', ylabel='target'>

# %%
from scipy import stats
z_score = np.abs(stats.zscore(df))
df=df[(z_score < 3).all(axis=1)]
print(df.describe())
# Out:
#                 A       target
# count  988.000000   988.000000
# mean     4.293332   520.623482
# std      8.459188   826.603082
# min      0.001848     0.000000
# 25%      0.291274     0.000000
# 50%      1.126978     0.000000
# 75%      4.209386  1419.500000
# max     76.728551  2298.000000

# %%
sns.scatterplot(data=df, x='A', y='target', hue='target')
# Out:
# <Axes: xlabel='A', ylabel='target'>

# %%
sns.histplot(data=df, kde=True, bins=20)
# Out:
# <Axes: ylabel='Count'>
